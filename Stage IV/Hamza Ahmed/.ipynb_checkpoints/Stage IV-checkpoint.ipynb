# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
import matplotlib.pyplot as plt

# Load data
data = pd.read_csv('US-Covid.csv')
data.head()
# Out:
#    countyFIPS      County Name State  StateFIPS  population  2020-06-01_cases  \
# 0        1001  Autauga County     AL          1       55869               233
# 1        1003  Baldwin County     AL          1      223234               292
# 2        1005  Barbour County     AL          1       24686               172
# 3        1007     Bibb County     AL          1       22394                76
# 4        1009   Blount County     AL          1       57826                63
#
#    2020-06-02_cases  2020-06-03_cases  2020-06-04_cases  2020-06-05_cases  \
# 0               238               239               241               248
# 1               292               292               293               296
# 2               175               177               177               183
# 3                76                76                76                76
# 4                63                63                63                64
#
#    ...  2020-12-25_deaths  2020-12-26_deaths  2020-12-27_deaths  \
# 0  ...                 46                 46                 47
# 1  ...                151                151                152
# 2  ...                 32                 32                 32
# 3  ...                 42                 42                 42
# 4  ...                 58                 58                 58
#
#    2020-12-28_deaths  2020-12-29_deaths  2020-12-30_deaths  2020-12-31_deaths  \
# 0                 47                 47                 48                 48
# 1                152                156                160                161
# 2                 32                 32                 32                 32
# 3                 42                 42                 46                 46
# 4                 58                 58                 63                 63
#
#    2021-01-01_deaths  2021-01-02_deaths  2021-01-03_deaths
# 0                 50                 50                 50
# 1                169                169                169
# 2                 33                 33                 33
# 3                 46                 46                 46
# 4                 63                 63                 63
#
# [5 rows x 439 columns]

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
import matplotlib.pyplot as plt

# Load data
enrichment_data = pd.read_csv(r"C:\Users\bluev\Downloads\5_states_and_CA.csv")
covid_data = pd.read_csv('US-Covid.csv')

# Filter for California and find the top 5 counties by total cases
covid_data_ca = covid_data[covid_data['State'] == 'CA']
# Use .loc to avoid SettingWithCopyWarning
covid_data_ca = covid_data_ca.copy()  # Create a copy of the DataFrame to work on
covid_data_ca['total_cases'] = covid_data_ca[[col for col in covid_data_ca.columns if '_cases' in col]].sum(axis=1)

top_counties = covid_data_ca.nlargest(5, 'total_cases')['County Name']

# Perform analysis for each top county
for county in top_counties:
    county_data = covid_data_ca[covid_data_ca['County Name'] == county]

    # Melt the DataFrame to long format
    county_data_long = county_data.melt(id_vars=['County Name', 'State', 'population'], 
                                         var_name='date_cases', 
                                         value_name='cases')
    
    # Extract date from the 'date_cases' column
    county_data_long['date'] = county_data_long['date_cases'].str.extract(r'(\d{4}-\d{2}-\d{2})')[0]
    county_data_long['date'] = pd.to_datetime(county_data_long['date'], errors='coerce')
    
    # Drop rows where date is NaT or cases are NaN
    county_data_long = county_data_long.dropna(subset=['date', 'cases'])
    
    # Set the date as index
    county_data_long = county_data_long.set_index('date')
    
    # Prepare regression model inputs
    county_cases = county_data_long['cases'].values
    days_since_start = np.arange(len(county_cases)).reshape(-1, 1)
    X = days_since_start
    y_cases = county_cases
    
    # Linear Regression
    linear_model = LinearRegression()
    linear_model.fit(X, y_cases)
    y_cases_pred_linear = linear_model.predict(X)
    
    # Polynomial Regression (Degree 3)
    poly = PolynomialFeatures(degree=3)
    X_poly = poly.fit_transform(X)
    poly_model = LinearRegression()
    poly_model.fit(X_poly, y_cases)
    y_cases_pred_poly = poly_model.predict(X_poly)
    
    # RMSE Calculation
    rmse_linear = np.sqrt(np.mean((y_cases - y_cases_pred_linear) ** 2))
    rmse_poly = np.sqrt(np.mean((y_cases - y_cases_pred_poly) ** 2))
    
    # Plot
    plt.figure(figsize=(10, 5))
    plt.plot(X, y_cases, label="Actual Cases")
    plt.plot(X, y_cases_pred_linear, label="Linear Prediction", linestyle="--")
    plt.plot(X, y_cases_pred_poly, label="Polynomial Prediction", linestyle="--")
    plt.title(f"{county} COVID-19 Cases Prediction")
    plt.xlabel("Days since 2020-06-01")
    plt.ylabel("New Cases")
    plt.legend()
    plt.show()

# %%
enrichment_data.head()
# Out:
#                    Label (Grouping) California!!Estimate California!!Percent  \
# 0                 EMPLOYMENT STATUS                  NaN                 NaN
# 1      Population 16 years and over           31,403,964          31,403,964
# 2                    In labor force           20,016,955               63.7%
# 3              Civilian labor force           19,875,973               63.3%
# 4                          Employed           18,646,894               59.4%
#
#   Idaho!!Estimate Idaho!!Percent Montana!!Estimate Montana!!Percent  \
# 0             NaN            NaN               NaN              NaN
# 1       1,360,062      1,360,062           859,185          859,185
# 2         858,590          63.1%           545,629            63.5%
# 3         854,040          62.8%           542,584            63.2%
# 4         818,085          60.2%           520,043            60.5%
#
#   Oregon!!Estimate Oregon!!Percent Washington!!Estimate Washington!!Percent  \
# 0              NaN             NaN                  NaN                 NaN
# 1        3,408,422       3,408,422            6,038,812           6,038,812
# 2        2,134,435           62.6%            3,904,996               64.7%
# 3        2,130,784           62.5%            3,848,596               63.7%
# 4        2,014,487           59.1%            3,660,034               60.6%
#
#   Wyoming!!Estimate Wyoming!!Percent
# 0               NaN              NaN
# 1           461,417          461,417
# 2           303,956            65.9%
# 3           300,597            65.1%
# 4           287,375            62.3%

# %%
import pandas as pd
import numpy as np
from scipy import stats

# Load enrichment data and COVID data for California
enrichment_data = pd.read_csv(r"C:\Users\bluev\Downloads\5_states_and_CA.csv")
covid_data = pd.read_csv(r"C:\Users\bluev\Downloads\Group7ClassProject\Stage II\Hamza Ahmed\filtered_super_dates_June2020_Jan2021_and_6_states.csv")

# Assume 'cases_per_100k' column exists, or calculate it if needed:
# Here, "cases_per_100k" should be calculated per county as the total cases divided by the population in that county, scaled to per 100,000 people.

# Calculate cases per 100,000 population for each county in California
covid_data_ca = covid_data[covid_data['State'] == 'CA']
covid_data_ca['cases_per_100k'] = (covid_data_ca[[col for col in covid_data_ca.columns if '_cases' in col]].sum(axis=1) / covid_data_ca['population']) * 100000

# Merge COVID data with enrichment data on relevant fields (adjust if necessary)
# Ensure both datasets have matching columns for merging (e.g., by county or other appropriate key)
merged_data = covid_data_ca.merge(enrichment_data, left_on='County Name', right_on='Label (Grouping)', how='left')

# Define T-test function
def perform_t_test(data, enrichment_column, outcome_column='cases_per_100k'):
    # Divide into high and low groups based on median of enrichment variable
    median_value = data[enrichment_column].median()
    high_group = data[data[enrichment_column] > median_value][outcome_column]
    low_group = data[data[enrichment_column] <= median_value][outcome_column]
    
    # Perform T-test
    t_stat, p_value = stats.ttest_ind(high_group, low_group)
    print(f"T-test for {enrichment_column}: t-statistic = {t_stat}, p-value = {p_value}")

# Perform T-tests for selected variables
perform_t_test(merged_data, 'Civilian labor force')
perform_t_test(merged_data, 'Employed')
perform_t_test(merged_data, 'With health insurance coverage')
# Out:
# C:\Users\bluev\AppData\Local\Temp\ipykernel_27940\4159737611.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covid_data_ca['cases_per_100k'] = (covid_data_ca[[col for col in covid_data_ca.columns if '_cases' in col]].sum(axis=1) / covid_data_ca['population']) * 100000
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27940\4159737611.py in ?()
#      14 covid_data_ca['cases_per_100k'] = (covid_data_ca[[col for col in covid_data_ca.columns if '_cases' in col]].sum(axis=1) / covid_data_ca['population']) * 100000
#      15
#      16 # Merge COVID data with enrichment data on relevant fields (adjust if necessary)
#      17 # Ensure both datasets have matching columns for merging (e.g., by county or other appropriate key)
# ---> 18 merged_data = covid_data_ca.merge(enrichment_data, left_on='County Name', right_on='Label (Grouping)', how='left')
#      19
#      20 # Define T-test function
#      21 def perform_t_test(data, enrichment_column, outcome_column='cases_per_100k'):
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10828         validate: MergeValidate | None = None,
#   10829     ) -> DataFrame:
#   10830         from pandas.core.reshape.merge import merge
#   10831
# > 10832         return merge(
#   10833             self,
#   10834             right,
#   10835             how=how,
#
# ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#     173             how=how,
#
# ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     790             self.right_join_keys,
#     791             self.join_names,
#     792             left_drop,
#     793             right_drop,
# --> 794         ) = self._get_merge_keys()
#     795
#     796         if left_drop:
#     797             self.left = self.left._drop_labels_or_levels(left_drop)
#
# ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py in ?(self)
#    1306                     if lk is not None:
#    1307                         # Then we're either Hashable or a wrong-length arraylike,
#    1308                         #  the latter of which will raise
#    1309                         lk = cast(Hashable, lk)
# -> 1310                         left_keys.append(left._get_label_or_level_values(lk))
#    1311                         join_names.append(lk)
#    1312                     else:
#    1313                         # work-around for merge_asof(left_index=True)
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1907             values = self.xs(key, axis=other_axes[0])._values
#    1908         elif self._is_level_reference(key, axis=axis):
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#    1914         if values.ndim > 1:
#
# KeyError: 'County Name'

# %%
import pandas as pd
import numpy as np
from scipy import stats

# Load enrichment data and COVID data for California
enrichment_data = pd.read_csv(r"C:\Users\bluev\Downloads\5_states_and_CA.csv")
covid_data = pd.read_csv(r"C:\Users\bluev\Downloads\Group7ClassProject\Stage II\Hamza Ahmed\filtered_super_dates_June2020_Jan2021_and_6_states.csv")

# Step 1: Filter COVID data for California and calculate cases per 100,000
covid_data_ca = covid_data[covid_data['State'] == 'CA'].copy()
covid_data_ca['total_cases'] = covid_data_ca[[col for col in covid_data_ca.columns if '_cases' in col]].sum(axis=1)
covid_data_ca['cases_per_100k'] = (covid_data_ca['total_cases'] / covid_data_ca['population']) * 100000

# Step 2: Since county names don't match, use state-level average cases per 100k for California
california_avg_cases_per_100k = covid_data_ca['cases_per_100k'].mean()
enrichment_data['cases_per_100k'] = california_avg_cases_per_100k

# Step 3: Define T-test function
def perform_t_test(data, enrichment_column, outcome_column='cases_per_100k'):
    # Check if the column exists in the data
    if enrichment_column not in data.columns:
        print(f"{enrichment_column} column not found in enrichment data.")
        return
    
    # Divide into high and low groups based on median of the enrichment variable
    median_value = data[enrichment_column].median()
    high_group = data[data[enrichment_column] > median_value][outcome_column]
    low_group = data[data[enrichment_column] <= median_value][outcome_column]
    
    # Perform T-test
    t_stat, p_value = stats.ttest_ind(high_group, low_group, equal_var=False)
    print(f"T-test for {enrichment_column}: t-statistic = {t_stat:.4f}, p-value = {p_value:.4f}")

# Step 4: Perform T-tests for selected variables
# Only columns that exist in the dataset will be tested
for column in ['Civilian labor force', 'Employed', 'With health insurance coverage']:
    perform_t_test(enrichment_data, column)
# Out:
# Civilian labor force column not found in enrichment data.
# Employed column not found in enrichment data.
# With health insurance coverage column not found in enrichment data.

# %%
enrichment_data.head()
# Out:
#                    Label (Grouping) California!!Estimate California!!Percent  \
# 0                 EMPLOYMENT STATUS                  NaN                 NaN
# 1      Population 16 years and over           31,403,964          31,403,964
# 2                    In labor force           20,016,955               63.7%
# 3              Civilian labor force           19,875,973               63.3%
# 4                          Employed           18,646,894               59.4%
#
#   Idaho!!Estimate Idaho!!Percent Montana!!Estimate Montana!!Percent  \
# 0             NaN            NaN               NaN              NaN
# 1       1,360,062      1,360,062           859,185          859,185
# 2         858,590          63.1%           545,629            63.5%
# 3         854,040          62.8%           542,584            63.2%
# 4         818,085          60.2%           520,043            60.5%
#
#   Oregon!!Estimate Oregon!!Percent Washington!!Estimate Washington!!Percent  \
# 0              NaN             NaN                  NaN                 NaN
# 1        3,408,422       3,408,422            6,038,812           6,038,812
# 2        2,134,435           62.6%            3,904,996               64.7%
# 3        2,130,784           62.5%            3,848,596               63.7%
# 4        2,014,487           59.1%            3,660,034               60.6%
#
#   Wyoming!!Estimate Wyoming!!Percent  cases_per_100k
# 0               NaN              NaN             inf
# 1           461,417          461,417             inf
# 2           303,956            65.9%             inf
# 3           300,597            65.1%             inf
# 4           287,375            62.3%             inf

# %%
import pandas as pd
import numpy as np
from scipy import stats

# Load enrichment data and COVID data for California
enrichment_data = pd.read_csv(r"C:\Users\bluev\Downloads\5_states_and_CA.csv")
covid_data = pd.read_csv(r"C:\Users\bluev\Downloads\Group7ClassProject\Stage II\Hamza Ahmed\filtered_super_dates_June2020_Jan2021_and_6_states.csv")

# Step 1: Reshape enrichment data to make rows into columns
# Filter rows that are of interest and pivot them into a single-row DataFrame
columns_of_interest = ["Civilian labor force", "Employed", "With health insurance coverage"]
enrichment_data_filtered = enrichment_data[enrichment_data['Label (Grouping)'].isin(columns_of_interest)]
enrichment_data_pivoted = enrichment_data_filtered.pivot_table(
    index=None,
    columns="Label (Grouping)",
    values="California!!Estimate"  # Adjust if necessary to use the correct state's column
).reset_index(drop=True)

# Step 2: Add California average cases per 100k to the pivoted DataFrame
covid_data_ca = covid_data[covid_data['State'] == 'CA'].copy()
covid_data_ca['total_cases'] = covid_data_ca[[col for col in covid_data_ca.columns if '_cases' in col]].sum(axis=1)
covid_data_ca['cases_per_100k'] = (covid_data_ca['total_cases'] / covid_data_ca['population']) * 100000
california_avg_cases_per_100k = covid_data_ca['cases_per_100k'].mean()
enrichment_data_pivoted['cases_per_100k'] = california_avg_cases_per_100k

# Step 3: Define T-test function
def perform_t_test(data, enrichment_column, outcome_column='cases_per_100k'):
    if enrichment_column not in data.columns:
        print(f"{enrichment_column} column not found in enrichment data.")
        return
    
    median_value = data[enrichment_column].median()
    high_group = data[data[enrichment_column] > median_value][outcome_column]
    low_group = data[data[enrichment_column] <= median_value][outcome_column]
    
    t_stat, p_value = stats.ttest_ind(high_group, low_group, equal_var=False)
    print(f"T-test for {enrichment_column}: t-statistic = {t_stat:.4f}, p-value = {p_value:.4f}")

# Step 4: Perform T-tests for selected variables
for column in columns_of_interest:
    perform_t_test(enrichment_data_pivoted, column)
# Out:
# Civilian labor force column not found in enrichment data.
# Employed column not found in enrichment data.
# With health insurance coverage column not found in enrichment data.

# %%
enrichment_data_1 = pd.read_csv(r"C:\Users\bluev\OneDrive\Documents\Californa county.csv")

# %%
e_data.head()
# Out:
#                    Label (Grouping) California!!Estimate  \
# 0                 EMPLOYMENT STATUS                  NaN
# 1      Population 16 years and over           31,584,340
# 2                    In labor force           20,298,562
# 3              Civilian labor force           20,137,422
# 4                          Employed           19,026,566
#
#   California!!Margin of Error California!!Percent  \
# 0                         NaN                 NaN
# 1                     ±10,617          31,584,340
# 2                     ±45,624               64.3%
# 3                     ±44,866               63.8%
# 4                     ±48,244               60.2%
#
#   California!!Percent Margin of Error Alameda County, California!!Estimate  \
# 0                                 NaN                                  NaN
# 1                                 (X)                            1,344,616
# 2                                ±0.1                              901,793
# 3                                ±0.1                              897,874
# 4                                ±0.2                              850,555
#
#   Alameda County, California!!Margin of Error  \
# 0                                         NaN
# 1                                      ±1,984
# 2                                      ±9,239
# 3                                      ±9,621
# 4                                     ±11,204
#
#   Alameda County, California!!Percent  \
# 0                                 NaN
# 1                           1,344,616
# 2                               67.1%
# 3                               66.8%
# 4                               63.3%
#
#   Alameda County, California!!Percent Margin of Error  \
# 0                                                NaN
# 1                                                (X)
# 2                                               ±0.7
# 3                                               ±0.7
# 4                                               ±0.8
#
#   Butte County, California!!Estimate  ... Ventura County, California!!Percent  \
# 0                                NaN  ...                                 NaN
# 1                            170,637  ...                             675,002
# 2                            101,973  ...                               64.5%
# 3                            101,483  ...                               63.8%
# 4                             94,472  ...                               60.4%
#
#   Ventura County, California!!Percent Margin of Error  \
# 0                                                NaN
# 1                                                (X)
# 2                                               ±0.7
# 3                                               ±0.7
# 4                                               ±0.8
#
#   Yolo County, California!!Estimate Yolo County, California!!Margin of Error  \
# 0                               NaN                                      NaN
# 1                           184,580                                   ±1,052
# 2                           117,713                                   ±3,900
# 3                           117,058                                   ±3,878
# 4                           111,247                                   ±4,094
#
#   Yolo County, California!!Percent  \
# 0                              NaN
# 1                          184,580
# 2                            63.8%
# 3                            63.4%
# 4                            60.3%
#
#   Yolo County, California!!Percent Margin of Error  \
# 0                                              NaN
# 1                                              (X)
# 2                                             ±2.0
# 3                                             ±2.0
# 4                                             ±2.1
#
#   Yuba County, California!!Estimate Yuba County, California!!Margin of Error  \
# 0                               NaN                                      NaN
# 1                            64,604                                     ±511
# 2                            39,800                                   ±2,324
# 3                            37,099                                   ±2,467
# 4                            34,049                                   ±2,563
#
#   Yuba County, California!!Percent  \
# 0                              NaN
# 1                           64,604
# 2                            61.6%
# 3                            57.4%
# 4                            52.7%
#
#   Yuba County, California!!Percent Margin of Error
# 0                                              NaN
# 1                                              (X)
# 2                                             ±3.6
# 3                                             ±3.8
# 4                                             ±4.0
#
# [5 rows x 173 columns]

# %% [markdown]
# # New Branch

# %%
enrichment_data = pd.read_csv(r"C:\Users\bluev\OneDrive\Documents\Economy.csv")
covid_data = pd.read_csv('US-Covid.csv')

# %%
enrichment_data.head()
# Out:
#                    Label (Grouping) California!!Estimate California!!Percent
# 0                 EMPLOYMENT STATUS                  NaN                 NaN
# 1      Population 16 years and over           31,403,964          31,403,964
# 2                    In labor force           20,016,955               63.7%
# 3              Civilian labor force           19,875,973               63.3%
# 4                          Employed           18,646,894               59.4%

# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# Load your datasets
enrichment_data = pd.read_csv(r"C:\Users\bluev\OneDrive\Documents\Economy.csv")
covid_data = pd.read_csv('US-Covid.csv')

# Hypothesis Testing Function
def perform_hypothesis_test(covid_data, enrichment_data, employment_column, covid_column, threshold):
    # Define high and low groups based on the threshold
    high_group = enrichment_data[enrichment_data[employment_column] > threshold]
    low_group = enrichment_data[enrichment_data[employment_column] <= threshold]

    # Combine COVID cases data for both groups
    high_cases = covid_data[covid_data['County Name'].isin(high_group['County Name'])][covid_column]
    low_cases = covid_data[covid_data['County Name'].isin(low_group['County Name'])][covid_column]

    # Perform two-sample t-test
    t_stat, p_value = stats.ttest_ind(high_cases, low_cases, equal_var=False)  # Welch's t-test
    return t_stat, p_value

# 1. Civilian Labor Force Hypothesis
t_stat_civilian, p_value_civilian = perform_hypothesis_test(covid_data, enrichment_data, 'Civilian labor force', '2020-06-01_cases', 100000)
print(f'Civilian Labor Force - T-statistic: {t_stat_civilian}, P-value: {p_value_civilian}')

# 2. Employed Hypothesis
t_stat_employed, p_value_employed = perform_hypothesis_test(covid_data, enrichment_data, 'Employed', '2020-06-01_cases', 500000)
print(f'Employed - T-statistic: {t_stat_employed}, P-value: {p_value_employed}')

# 3. Health Insurance Coverage Hypothesis
# Assuming you have a variable for health insurance coverage in your dataset
# Modify this line as needed based on your data
t_stat_health_insurance, p_value_health_insurance = perform_hypothesis_test(covid_data, enrichment_data, 'With health insurance coverage', '2020-06-01_cases', 70)
print(f'Health Insurance Coverage - T-statistic: {t_stat_health_insurance}, P-value: {p_value_health_insurance}')

# Visualizing results
def plot_hypothesis_results(enrichment_data, covid_data, employment_column, covid_column):
    plt.figure(figsize=(10, 6))
    plt.title(f'COVID-19 Cases vs {employment_column}')

    # Create bar plots for high and low groups
    high_group = enrichment_data[enrichment_data[employment_column] > threshold]
    low_group = enrichment_data[enrichment_data[employment_column] <= threshold]

    high_cases = covid_data[covid_data['County Name'].isin(high_group['County Name'])][covid_column]
    low_cases = covid_data[covid_data['County Name'].isin(low_group['County Name'])][covid_column]

    plt.bar(['High', 'Low'], [high_cases.mean(), low_cases.mean()], color=['green', 'red'])
    plt.ylabel('Average COVID-19 Cases')
    plt.show()

# Plot results for each hypothesis
plot_hypothesis_results(enrichment_data, covid_data, 'Civilian labor force', '2020-06-01_cases')
plot_hypothesis_results(enrichment_data, covid_data, 'Employed', '2020-06-01_cases')
plot_hypothesis_results(enrichment_data, covid_data, 'With health insurance coverage', '2020-06-01_cases')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Civilian labor force'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[60], line 25
#      22     return t_stat, p_value
#      24 # 1. Civilian Labor Force Hypothesis
# ---> 25 t_stat_civilian, p_value_civilian = perform_hypothesis_test(covid_data, enrichment_data, 'Civilian labor force', '2020-06-01_cases', 100000)
#      26 print(f'Civilian Labor Force - T-statistic: {t_stat_civilian}, P-value: {p_value_civilian}')
#      28 # 2. Employed Hypothesis
#
# Cell In[60], line 13, in perform_hypothesis_test(covid_data, enrichment_data, employment_column, covid_column, threshold)
#      11 def perform_hypothesis_test(covid_data, enrichment_data, employment_column, covid_column, threshold):
#      12     # Define high and low groups based on the threshold
# ---> 13     high_group = enrichment_data[enrichment_data[employment_column] > threshold]
#      14     low_group = enrichment_data[enrichment_data[employment_column] <= threshold]
#      16     # Combine COVID cases data for both groups
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Civilian labor force'

# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# Load your datasets
enrichment_data = pd.read_csv(r"C:\Users\bluev\OneDrive\Documents\Economy.csv")
covid_data = pd.read_csv('US-Covid.csv')

# Extract relevant values from the enrichment dataset
civilian_labor_force = enrichment_data.loc[enrichment_data['Label (Grouping)'] == 'Civilian labor force', 'California!!Estimate'].values[0]
employed = enrichment_data.loc[enrichment_data['Label (Grouping)'] == 'Employed', 'California!!Estimate'].values[0]
# Assuming 'With health insurance coverage' is similar; replace the label accordingly
health_insurance_coverage = enrichment_data.loc[enrichment_data['Label (Grouping)'] == 'With health insurance coverage', 'California!!Estimate'].values[0]

# Convert COVID-19 cases to numeric values
covid_data.columns = covid_data.columns.str.replace('_cases', '')  # Remove '_cases' from column names for easier access
covid_data.iloc[:, 5:] = covid_data.iloc[:, 5:].apply(pd.to_numeric, errors='coerce')  # Convert case columns to numeric

# Hypothesis Testing Function
def perform_hypothesis_test(covid_data, employment_value, covid_column):
    # Get cases per 100,000 population for the specified date
    covid_cases_per_100k = covid_data[covid_column] / (covid_data['population'] / 100000)

    # Create high and low groups based on employment value
    if employment_value > covid_cases_per_100k.mean():
        high_cases = covid_cases_per_100k[covid_cases_per_100k > covid_cases_per_100k.mean()]
        low_cases = covid_cases_per_100k[covid_cases_per_100k <= covid_cases_per_100k.mean()]
    else:
        high_cases = covid_cases_per_100k[covid_cases_per_100k <= covid_cases_per_100k.mean()]
        low_cases = covid_cases_per_100k[covid_cases_per_100k > covid_cases_per_100k.mean()]

    # Perform two-sample t-test
    t_stat, p_value = stats.ttest_ind(high_cases, low_cases, equal_var=False)  # Welch's t-test
    return t_stat, p_value

# Perform hypothesis tests
t_stat_civilian, p_value_civilian = perform_hypothesis_test(covid_data, civilian_labor_force, '2020-06-01_cases')
print(f'Civilian Labor Force - T-statistic: {t_stat_civilian}, P-value: {p_value_civilian}')

t_stat_employed, p_value_employed = perform_hypothesis_test(covid_data, employed, '2020-06-01_cases')
print(f'Employed - T-statistic: {t_stat_employed}, P-value: {p_value_employed}')

# Assuming you have a variable for health insurance coverage in your dataset
t_stat_health_insurance, p_value_health_insurance = perform_hypothesis_test(covid_data, health_insurance_coverage, '2020-06-01_cases')
print(f'Health Insurance Coverage - T-statistic: {t_stat_health_insurance}, P-value: {p_value_health_insurance}')

# Optional: Visualization
def plot_hypothesis_results(covid_data, employment_value, covid_column):
    plt.figure(figsize=(10, 6))
    plt.title('COVID-19 Cases Based on Employment Data')

    covid_cases_per_100k = covid_data[covid_column] / (covid_data['population'] / 100000)
    
    plt.hist(covid_cases_per_100k, bins=30, alpha=0.5, color='blue', label='COVID-19 Cases per 100,000')
    plt.axvline(employment_value, color='red', linestyle='dashed', linewidth=2, label='Employment Threshold')
    
    plt.xlabel('Cases per 100,000')
    plt.ylabel('Frequency')
    plt.legend()
    plt.show()

# Plot results for each hypothesis
plot_hypothesis_results(covid_data, civilian_labor_force, '2020-06-01_cases')
plot_hypothesis_results(covid_data, employed, '2020-06-01_cases')
plot_hypothesis_results(covid_data, health_insurance_coverage, '2020-06-01_cases')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[62], line 11
#       8 covid_data = pd.read_csv('US-Covid.csv')
#      10 # Extract relevant values from the enrichment dataset
# ---> 11 civilian_labor_force = enrichment_data.loc[enrichment_data['Label (Grouping)'] == 'Civilian labor force', 'California!!Estimate'].values[0]
#      12 employed = enrichment_data.loc[enrichment_data['Label (Grouping)'] == 'Employed', 'California!!Estimate'].values[0]
#      13 # Assuming 'With health insurance coverage' is similar; replace the label accordingly
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
import pandas as pd

# Load your enrichment dataset
enrichment_data = pd.read_csv(r"C:\Users\bluev\OneDrive\Documents\Economy.csv")

# Check unique values in the 'Label (Grouping)' column
print(enrichment_data['Label (Grouping)'].unique())

# Attempt to extract values for the hypotheses
try:
    civilian_labor_force = enrichment_data.loc[enrichment_data['Label (Grouping)'].str.strip() == 'Civilian labor force', 'California!!Estimate'].values[0]
    employed = enrichment_data.loc[enrichment_data['Label (Grouping)'].str.strip() == 'Employed', 'California!!Estimate'].values[0]
    health_insurance_coverage = enrichment_data.loc[enrichment_data['Label (Grouping)'].str.strip() == 'With health insurance coverage', 'California!!Estimate'].values[0]
except IndexError as e:
    print("IndexError: Could not find one of the labels in the enrichment dataset.")
    print(e)

# Print the extracted values to confirm they were obtained correctly
print(f'Civilian Labor Force: {civilian_labor_force}')
print(f'Employed: {employed}')
print(f'Health Insurance Coverage: {health_insurance_coverage}')
# Out:
# ['EMPLOYMENT STATUS' '\xa0\xa0\xa0\xa0Population 16 years and over'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0In labor force'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Civilian labor force'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Employed'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Unemployed'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Armed Forces'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Not in labor force'
#  '\xa0\xa0\xa0\xa0Civilian labor force'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Unemployment Rate'
#  '\xa0\xa0\xa0\xa0Females 16 years and over'
#  '\xa0\xa0\xa0\xa0Own children of the householder under 6 years'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0All parents in family in labor force'
#  '\xa0\xa0\xa0\xa0Own children of the householder 6 to 17 years'
#  'COMMUTING TO WORK' '\xa0\xa0\xa0\xa0Workers 16 years and over'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Car, truck, or van -- drove alone'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Car, truck, or van -- carpooled'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Public transportation (excluding taxicab)'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Walked'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Other means'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Worked from home'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Mean travel time to work (minutes)'
#  'OCCUPATION'
#  '\xa0\xa0\xa0\xa0Civilian employed population 16 years and over'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Management, business, science, and arts occupations'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Service occupations'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Sales and office occupations'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Natural resources, construction, and maintenance occupations'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Production, transportation, and material moving occupations'
#  'INDUSTRY'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Agriculture, forestry, fishing and hunting, and mining'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Construction'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Manufacturing'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Wholesale trade'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Retail trade'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Transportation and warehousing, and utilities'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Information'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Finance and insurance, and real estate and rental and leasing'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Professional, scientific, and management, and administrative and waste management services'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Educational services, and health care and social assistance'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Arts, entertainment, and recreation, and accommodation and food services'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Other services, except public administration'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Public administration' 'CLASS OF WORKER'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Private wage and salary workers'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Government workers'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Self-employed in own not incorporated business workers'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Unpaid family workers'
#  'INCOME AND BENEFITS (IN 2020 INFLATION-ADJUSTED DOLLARS)'
#  '\xa0\xa0\xa0\xa0Total households'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Less than $10,000'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0$10,000 to $14,999'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0$15,000 to $24,999'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0$25,000 to $34,999'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0$35,000 to $49,999'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0$50,000 to $74,999'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0$75,000 to $99,999'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0$100,000 to $149,999'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0$150,000 to $199,999'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0$200,000 or more'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Median household income (dollars)'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Mean household income (dollars)'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With earnings'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Mean earnings (dollars)'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With Social Security'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Mean Social Security income (dollars)'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With retirement income'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Mean retirement income (dollars)'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With Supplemental Security Income'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Mean Supplemental Security Income (dollars)'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With cash public assistance income'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Mean cash public assistance income (dollars)'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With Food Stamp/SNAP benefits in the past 12 months'
#  '\xa0\xa0\xa0\xa0Families'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Median family income (dollars)'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Mean family income (dollars)'
#  '\xa0\xa0\xa0\xa0Per capita income (dollars)'
#  '\xa0\xa0\xa0\xa0Nonfamily households'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Median nonfamily income (dollars)'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Mean nonfamily income (dollars)'
#  '\xa0\xa0\xa0\xa0Median earnings for workers (dollars)'
#  '\xa0\xa0\xa0\xa0Median earnings for male full-time, year-round workers (dollars)'
#  '\xa0\xa0\xa0\xa0Median earnings for female full-time, year-round workers (dollars)'
#  'HEALTH INSURANCE COVERAGE'
#  '\xa0\xa0\xa0\xa0Civilian noninstitutionalized population'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With health insurance coverage'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With private health insurance'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With public coverage'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0No health insurance coverage'
#  '\xa0\xa0\xa0\xa0Civilian noninstitutionalized population under 19 years'
#  '\xa0\xa0\xa0\xa0Civilian noninstitutionalized population 19 to 64 years'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0In labor force:'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Employed:'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With health insurance coverage'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With private health insurance'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With public coverage'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0No health insurance coverage'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Unemployed:'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Not in labor force:'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With health insurance coverage'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With private health insurance'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With public coverage'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0No health insurance coverage'
#  'PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL'
#  '\xa0\xa0\xa0\xa0All families'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With related children of the householder under 18 years'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With related children of the householder under 5 years only'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Married couple families'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With related children of the householder under 18 years'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With related children of the householder under 5 years only'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Families with female householder, no spouse present'
#  '\xa0\xa0\xa0\xa0All people'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Under 18 years'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Related children of the householder under 18 years'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Related children of the householder under 5 years'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Related children of the householder 5 to 17 years'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa018 years and over'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa018 to 64 years'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa065 years and over'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0People in families'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Unrelated individuals 15 years and over']
# Civilian Labor Force: 19,875,973
# Employed: 18,646,894
# Health Insurance Coverage: 36,032,553

# %%
import pandas as pd

# Load the datasets
enrichment_data = pd.read_csv(r"C:\Users\bluev\OneDrive\Documents\Economy.csv")
covid_data = pd.read_csv('US-Covid.csv')
print(enrichment_data.columns)
print(enrichment_data['Label (Grouping)'].unique())
enrichment_data['Label (Grouping)'] = enrichment_data['Label (Grouping)'].str.strip()
filtered_data = enrichment_data[enrichment_data['Label (Grouping)'] == 'Civilian labor force']
print(filtered_data)

# Clean the column names by stripping whitespace
enrichment_data.columns = enrichment_data.columns.str.strip()

# Extract relevant values from the enrichment dataset
civilian_labor_force = enrichment_data.loc[enrichment_data['Label (Grouping)'] == 'Civilian labor force', 'California!!Estimate'].values[0]
employed = enrichment_data.loc[enrichment_data['Label (Grouping)'] == 'Employed', 'California!!Estimate'].values[0]
health_insurance_coverage = enrichment_data.loc[enrichment_data['Label (Grouping)'] == 'With health insurance coverage', 'California!!Estimate'].values[0]

print(f"Civilian Labor Force: {civilian_labor_force}")
print(f"Employed: {employed}")
print(f"Health Insurance Coverage: {health_insurance_coverage}")
# Out:
# Index(['Label (Grouping)', 'California!!Estimate', 'California!!Percent'], dtype='object')
# ['EMPLOYMENT STATUS' '\xa0\xa0\xa0\xa0Population 16 years and over'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0In labor force'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Civilian labor force'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Employed'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Unemployed'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Armed Forces'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Not in labor force'
#  '\xa0\xa0\xa0\xa0Civilian labor force'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Unemployment Rate'
#  '\xa0\xa0\xa0\xa0Females 16 years and over'
#  '\xa0\xa0\xa0\xa0Own children of the householder under 6 years'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0All parents in family in labor force'
#  '\xa0\xa0\xa0\xa0Own children of the householder 6 to 17 years'
#  'COMMUTING TO WORK' '\xa0\xa0\xa0\xa0Workers 16 years and over'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Car, truck, or van -- drove alone'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Car, truck, or van -- carpooled'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Public transportation (excluding taxicab)'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Walked'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Other means'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Worked from home'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Mean travel time to work (minutes)'
#  'OCCUPATION'
#  '\xa0\xa0\xa0\xa0Civilian employed population 16 years and over'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Management, business, science, and arts occupations'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Service occupations'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Sales and office occupations'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Natural resources, construction, and maintenance occupations'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Production, transportation, and material moving occupations'
#  'INDUSTRY'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Agriculture, forestry, fishing and hunting, and mining'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Construction'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Manufacturing'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Wholesale trade'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Retail trade'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Transportation and warehousing, and utilities'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Information'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Finance and insurance, and real estate and rental and leasing'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Professional, scientific, and management, and administrative and waste management services'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Educational services, and health care and social assistance'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Arts, entertainment, and recreation, and accommodation and food services'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Other services, except public administration'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Public administration' 'CLASS OF WORKER'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Private wage and salary workers'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Government workers'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Self-employed in own not incorporated business workers'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Unpaid family workers'
#  'INCOME AND BENEFITS (IN 2020 INFLATION-ADJUSTED DOLLARS)'
#  '\xa0\xa0\xa0\xa0Total households'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Less than $10,000'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0$10,000 to $14,999'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0$15,000 to $24,999'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0$25,000 to $34,999'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0$35,000 to $49,999'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0$50,000 to $74,999'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0$75,000 to $99,999'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0$100,000 to $149,999'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0$150,000 to $199,999'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0$200,000 or more'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Median household income (dollars)'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Mean household income (dollars)'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With earnings'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Mean earnings (dollars)'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With Social Security'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Mean Social Security income (dollars)'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With retirement income'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Mean retirement income (dollars)'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With Supplemental Security Income'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Mean Supplemental Security Income (dollars)'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With cash public assistance income'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Mean cash public assistance income (dollars)'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With Food Stamp/SNAP benefits in the past 12 months'
#  '\xa0\xa0\xa0\xa0Families'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Median family income (dollars)'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Mean family income (dollars)'
#  '\xa0\xa0\xa0\xa0Per capita income (dollars)'
#  '\xa0\xa0\xa0\xa0Nonfamily households'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Median nonfamily income (dollars)'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Mean nonfamily income (dollars)'
#  '\xa0\xa0\xa0\xa0Median earnings for workers (dollars)'
#  '\xa0\xa0\xa0\xa0Median earnings for male full-time, year-round workers (dollars)'
#  '\xa0\xa0\xa0\xa0Median earnings for female full-time, year-round workers (dollars)'
#  'HEALTH INSURANCE COVERAGE'
#  '\xa0\xa0\xa0\xa0Civilian noninstitutionalized population'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With health insurance coverage'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With private health insurance'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With public coverage'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0No health insurance coverage'
#  '\xa0\xa0\xa0\xa0Civilian noninstitutionalized population under 19 years'
#  '\xa0\xa0\xa0\xa0Civilian noninstitutionalized population 19 to 64 years'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0In labor force:'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Employed:'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With health insurance coverage'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With private health insurance'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With public coverage'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0No health insurance coverage'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Unemployed:'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Not in labor force:'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With health insurance coverage'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With private health insurance'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With public coverage'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0No health insurance coverage'
#  'PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL'
#  '\xa0\xa0\xa0\xa0All families'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With related children of the householder under 18 years'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With related children of the householder under 5 years only'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Married couple families'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With related children of the householder under 18 years'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0With related children of the householder under 5 years only'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Families with female householder, no spouse present'
#  '\xa0\xa0\xa0\xa0All people'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Under 18 years'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Related children of the householder under 18 years'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Related children of the householder under 5 years'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Related children of the householder 5 to 17 years'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa018 years and over'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa018 to 64 years'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa065 years and over'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0People in families'
#  '\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0Unrelated individuals 15 years and over']
#         Label (Grouping) California!!Estimate California!!Percent
# 3   Civilian labor force           19,875,973               63.3%
# 8   Civilian labor force           19,875,973          19,875,973
# 12  Civilian labor force            9,170,541               57.7%
# Civilian Labor Force: 19,875,973
# Employed: 18,646,894
# Health Insurance Coverage: 36,032,553

# %%
import pandas as pd

# Load the datasets
enrichment_data = pd.read_csv(r"C:\Users\bluev\OneDrive\Documents\Economy.csv")
covid_data = pd.read_csv('US-Covid.csv')

# Clean the column names by stripping whitespace
enrichment_data.columns = enrichment_data.columns.str.strip()

# Clean 'Label (Grouping)' values by stripping whitespace and removing any non-breaking spaces
enrichment_data['Label (Grouping)'] = enrichment_data['Label (Grouping)'].str.strip().replace(r'\xa0', '', regex=True)

# Check the unique values again after cleaning
print(enrichment_data['Label (Grouping)'].unique())

# Extract relevant values from the enrichment dataset
civilian_labor_force = enrichment_data.loc[enrichment_data['Label (Grouping)'] == 'Civilian labor force', 'California!!Estimate'].values[0]
employed = enrichment_data.loc[enrichment_data['Label (Grouping)'] == 'Employed', 'California!!Estimate'].values[0]
health_insurance_coverage = enrichment_data.loc[enrichment_data['Label (Grouping)'] == 'With health insurance coverage', 'California!!Estimate'].values[0]

print(f"Civilian Labor Force: {civilian_labor_force}")
print(f"Employed: {employed}")
print(f"Health Insurance Coverage: {health_insurance_coverage}")
# Out:
# ['EMPLOYMENT STATUS' 'Population 16 years and over' 'In labor force'
#  'Civilian labor force' 'Employed' 'Unemployed' 'Armed Forces'
#  'Not in labor force' 'Unemployment Rate' 'Females 16 years and over'
#  'Own children of the householder under 6 years'
#  'All parents in family in labor force'
#  'Own children of the householder 6 to 17 years' 'COMMUTING TO WORK'
#  'Workers 16 years and over' 'Car, truck, or van -- drove alone'
#  'Car, truck, or van -- carpooled'
#  'Public transportation (excluding taxicab)' 'Walked' 'Other means'
#  'Worked from home' 'Mean travel time to work (minutes)' 'OCCUPATION'
#  'Civilian employed population 16 years and over'
#  'Management, business, science, and arts occupations'
#  'Service occupations' 'Sales and office occupations'
#  'Natural resources, construction, and maintenance occupations'
#  'Production, transportation, and material moving occupations' 'INDUSTRY'
#  'Agriculture, forestry, fishing and hunting, and mining' 'Construction'
#  'Manufacturing' 'Wholesale trade' 'Retail trade'
#  'Transportation and warehousing, and utilities' 'Information'
#  'Finance and insurance, and real estate and rental and leasing'
#  'Professional, scientific, and management, and administrative and waste management services'
#  'Educational services, and health care and social assistance'
#  'Arts, entertainment, and recreation, and accommodation and food services'
#  'Other services, except public administration' 'Public administration'
#  'CLASS OF WORKER' 'Private wage and salary workers' 'Government workers'
#  'Self-employed in own not incorporated business workers'
#  'Unpaid family workers'
#  'INCOME AND BENEFITS (IN 2020 INFLATION-ADJUSTED DOLLARS)'
#  'Total households' 'Less than $10,000' '$10,000 to $14,999'
#  '$15,000 to $24,999' '$25,000 to $34,999' '$35,000 to $49,999'
#  '$50,000 to $74,999' '$75,000 to $99,999' '$100,000 to $149,999'
#  '$150,000 to $199,999' '$200,000 or more'
#  'Median household income (dollars)' 'Mean household income (dollars)'
#  'With earnings' 'Mean earnings (dollars)' 'With Social Security'
#  'Mean Social Security income (dollars)' 'With retirement income'
#  'Mean retirement income (dollars)' 'With Supplemental Security Income'
#  'Mean Supplemental Security Income (dollars)'
#  'With cash public assistance income'
#  'Mean cash public assistance income (dollars)'
#  'With Food Stamp/SNAP benefits in the past 12 months' 'Families'
#  'Median family income (dollars)' 'Mean family income (dollars)'
#  'Per capita income (dollars)' 'Nonfamily households'
#  'Median nonfamily income (dollars)' 'Mean nonfamily income (dollars)'
#  'Median earnings for workers (dollars)'
#  'Median earnings for male full-time, year-round workers (dollars)'
#  'Median earnings for female full-time, year-round workers (dollars)'
#  'HEALTH INSURANCE COVERAGE' 'Civilian noninstitutionalized population'
#  'With health insurance coverage' 'With private health insurance'
#  'With public coverage' 'No health insurance coverage'
#  'Civilian noninstitutionalized population under 19 years'
#  'Civilian noninstitutionalized population 19 to 64 years'
#  'In labor force:' 'Employed:' 'Unemployed:' 'Not in labor force:'
#  'PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL'
#  'All families' 'With related children of the householder under 18 years'
#  'With related children of the householder under 5 years only'
#  'Married couple families'
#  'Families with female householder, no spouse present' 'All people'
#  'Under 18 years' 'Related children of the householder under 18 years'
#  'Related children of the householder under 5 years'
#  'Related children of the householder 5 to 17 years' '18 years and over'
#  '18 to 64 years' '65 years and over' 'People in families'
#  'Unrelated individuals 15 years and over']
# Civilian Labor Force: 19,875,973
# Employed: 18,646,894
# Health Insurance Coverage: 36,032,553

# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# Load your datasets
enrichment_data = pd.read_csv(r"C:\Users\bluev\OneDrive\Documents\Economy.csv")
covid_data = pd.read_csv('US-Covid.csv')

# Normalize strings in the 'Label (Grouping)' column
enrichment_data['Label (Grouping)'] = enrichment_data['Label (Grouping)'].str.strip().str.lower()

# Function to get values safely and ensure they are numeric
def get_value(label):
    try:
        value = enrichment_data.loc[
            enrichment_data['Label (Grouping)'] == label.lower(),
            'California!!Estimate'
        ].values[0]
        return pd.to_numeric(value, errors='coerce')  # Convert to numeric
    except IndexError:
        print(f"Warning: No data found for '{label}'")
        return None

# Extract relevant values from the enrichment dataset
civilian_labor_force = get_value('Civilian labor force')
employed = get_value('Employed')
health_insurance_coverage = get_value('With health insurance coverage')

# Check if any of the values are None and handle accordingly
if civilian_labor_force is None or employed is None or health_insurance_coverage is None:
    print("One or more required values are missing. Please check the enrichment dataset.")
else:
    # Convert COVID-19 cases to numeric values
    covid_data.columns = covid_data.columns.str.replace('_cases', '')  # Remove '_cases' from column names for easier access
    covid_data.iloc[:, 5:] = covid_data.iloc[:, 5:].apply(pd.to_numeric, errors='coerce')  # Convert case columns to numeric

    # Hypothesis Testing Function
    def perform_hypothesis_test(covid_data, employment_value, covid_column):
        # Get cases per 10,000 population for the specified date
        covid_cases_per_10k = covid_data[covid_column] / (covid_data['population'] / 10000)

        # Create high and low groups based on employment value
        mean_cases = covid_cases_per_10k.mean()
        
        # Ensure employment_value is a float
        employment_value = float(employment_value)

        if employment_value > mean_cases:
            high_cases = covid_cases_per_10k[covid_cases_per_10k > mean_cases]
            low_cases = covid_cases_per_10k[covid_cases_per_10k <= mean_cases]
        else:
            high_cases = covid_cases_per_10k[covid_cases_per_10k <= mean_cases]
            low_cases = covid_cases_per_10k[covid_cases_per_10k > mean_cases]

        # Perform two-sample t-test
        t_stat, p_value = stats.ttest_ind(high_cases, low_cases, equal_var=False)  # Welch's t-test
        return t_stat, p_value

    # Perform hypothesis tests
    t_stat_civilian, p_value_civilian = perform_hypothesis_test(covid_data, civilian_labor_force, '2020-06-01')
    print(f'Civilian Labor Force - T-statistic: {t_stat_civilian}, P-value: {p_value_civilian}')

    t_stat_employed, p_value_employed = perform_hypothesis_test(covid_data, employed, '2020-06-01')
    print(f'Employed - T-statistic: {t_stat_employed}, P-value: {p_value_employed}')

    t_stat_health_insurance, p_value_health_insurance = perform_hypothesis_test(covid_data, health_insurance_coverage, '2020-06-01')
    print(f'Health Insurance Coverage - T-statistic: {t_stat_health_insurance}, P-value: {p_value_health_insurance}')

# Function to plot hypothesis results
def plot_hypothesis_results(covid_data, employment_value, covid_column, label):
    plt.figure(figsize=(12, 6))  # Increase figure size for better readability
    plt.title(f'COVID-19 Cases Based on {label}')

    # Calculate cases per 10,000
    covid_cases_per_10k = covid_data[covid_column] / (covid_data['population'] / 10000)

    # Drop NaN values to avoid plotting issues
    covid_cases_per_10k = covid_cases_per_10k.dropna()

    # Create histogram with more bins and adjusted range
    plt.hist(covid_cases_per_10k, bins=50, alpha=0.7, color='blue', label='COVID-19 Cases per 10,000')

    # Add a vertical line for employment value
    plt.axvline(employment_value, color='red', linestyle='dashed', linewidth=2, label='Employment Threshold')

    # Set x-axis limits (adjust these values based on your data range)
    plt.xlim(0, covid_cases_per_10k.max() + 5)  # Add a little padding

    # Adding grid lines for better readability
    plt.grid(axis='y', linestyle='--', alpha=0.7)

    # Set labels and legend
    plt.xlabel('Cases per 10,000')
    plt.ylabel('Frequency')
    plt.legend()
    plt.tight_layout()  # Automatically adjust subplot parameters to give specified padding
    plt.show()

# Plot results for each hypothesis with appropriate labels
plot_hypothesis_results(covid_data, civilian_labor_force, '2020-06-01', 'Civilian Labor Force')
plot_hypothesis_results(covid_data, employed, '2020-06-01', 'Employed')
plot_hypothesis_results(covid_data, health_insurance_coverage, '2020-06-01', 'Health Insurance Coverage')
# Out:
# Civilian Labor Force - T-statistic: -24.70296798867943, P-value: 9.322492704777573e-102
# Employed - T-statistic: -24.70296798867943, P-value: 9.322492704777573e-102
# Health Insurance Coverage - T-statistic: -24.70296798867943, P-value: 9.322492704777573e-102

# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# Load your datasets
enrichment_data = pd.read_csv(r"C:\Users\bluev\OneDrive\Documents\Economy.csv")
covid_data = pd.read_csv('US-Covid.csv')

# Normalize strings in the 'Label (Grouping)' column
enrichment_data['Label (Grouping)'] = enrichment_data['Label (Grouping)'].str.strip().str.lower()

# Function to get values safely and ensure they are numeric
def get_value(label):
    try:
        value = enrichment_data.loc[
            enrichment_data['Label (Grouping)'] == label.lower(),
            'California!!Estimate'
        ].values[0]
        return pd.to_numeric(value, errors='coerce')  # Convert to numeric
    except IndexError:
        print(f"Warning: No data found for '{label}'")
        return None

# Extract relevant values from the enrichment dataset
civilian_labor_force = get_value('Civilian labor force')
employed = get_value('Employed')
health_insurance_coverage = get_value('With health insurance coverage')

# Check if any of the values are None and handle accordingly
if civilian_labor_force is None or employed is None or health_insurance_coverage is None:
    print("One or more required values are missing. Please check the enrichment dataset.")
else:
    # Convert COVID-19 cases to numeric values
    covid_data.columns = covid_data.columns.str.replace('_cases', '')  # Remove '_cases' from column names for easier access
    covid_data.iloc[:, 5:] = covid_data.iloc[:, 5:].apply(pd.to_numeric, errors='coerce')  # Convert case columns to numeric
    print(covid_data.head())  # Show a sample of the data
    print(covid_data.isna().sum())  # Check for NaN values

    # Define the date range
    start_date = '2020-06-01'
    end_date = '2021-01-10'
    date_range = pd.date_range(start=start_date, end=end_date)

    # Aggregate data
    aggregated_cases = pd.Series(index=covid_data.index, dtype=float).fillna(0)  # Initialize with 0

    for date in date_range:
        date_str = date.strftime('%Y-%m-%d')  # Convert date to string format
        if date_str in covid_data.columns:  # Check if the date column exists
            # Add to aggregated cases, ignoring NaN values
            aggregated_cases += covid_data[date_str].fillna(0)

    # Display the result
    print("Aggregated Cases after filling NaN:\n", aggregated_cases)

    # Calculate cases per 10,000 population for the aggregated data
    total_population = covid_data['population'].sum()
    if total_population > 0:  # Ensure total population is not zero
        cases_per_10k = aggregated_cases / (total_population / 10000)
    else:
        print("Total population is zero or invalid. Check the population column.")

    # Drop NaN values from cases_per_10k before hypothesis testing and plotting
    cases_per_10k = cases_per_10k.dropna()
    print("Cases per 10k:\n", cases_per_10k)

    # Hypothesis Testing Function
    def perform_hypothesis_test(cases_per_10k, employment_value):
        # Create high and low groups based on employment value
        mean_cases = cases_per_10k.mean()
        print(f"Mean cases: {mean_cases}")

        # Ensure employment_value is a float
        employment_value = float(employment_value)

        if employment_value > mean_cases:
            high_cases = cases_per_10k[cases_per_10k > mean_cases]
            low_cases = cases_per_10k[cases_per_10k <= mean_cases]
        else:
            high_cases = cases_per_10k[cases_per_10k <= mean_cases]
            low_cases = cases_per_10k[cases_per_10k > mean_cases]

        print(f"High cases count: {len(high_cases)}, Low cases count: {len(low_cases)}")

        # Perform two-sample t-test
        if len(high_cases) > 0 and len(low_cases) > 0:
            t_stat, p_value = stats.ttest_ind(high_cases, low_cases, equal_var=False)  # Welch's t-test
            return t_stat, p_value
        else:
            print("Warning: Not enough data to perform hypothesis test.")
            return np.nan, np.nan

    # Perform hypothesis tests
    t_stat_civilian, p_value_civilian = perform_hypothesis_test(cases_per_10k, civilian_labor_force)
    print(f'Overall - Civilian Labor Force - T-statistic: {t_stat_civilian}, P-value: {p_value_civilian}')

    t_stat_employed, p_value_employed = perform_hypothesis_test(cases_per_10k, employed)
    print(f'Overall - Employed - T-statistic: {t_stat_employed}, P-value: {p_value_employed}')

    t_stat_health_insurance, p_value_health_insurance = perform_hypothesis_test(cases_per_10k, health_insurance_coverage)
    print(f'Overall - Health Insurance Coverage - T-statistic: {t_stat_health_insurance}, P-value: {p_value_health_insurance}')

    # Function to plot hypothesis results
    def plot_hypothesis_results(cases_per_10k, employment_value, label):
        if cases_per_10k.empty:
            print(f"No data available to plot for {label}.")
            return
        
        plt.figure(figsize=(12, 6))  # Increase figure size for better readability
        plt.title(f'COVID-19 Cases Based on {label}')

        # Create histogram of aggregated cases per 10,000
        plt.hist(cases_per_10k, bins=50, alpha=0.7, color='blue', label='COVID-19 Cases per 10,000')

        # Add a vertical line for employment value
        plt.axvline(employment_value, color='red', linestyle='dashed', linewidth=2, label='Employment Threshold')

        # Set x-axis limits
        plt.xlim(0, cases_per_10k.max() + 5)  # Add a little padding

        # Adding grid lines for better readability
        plt.grid(axis='y', linestyle='--', alpha=0.7)

        # Set labels and legend
        plt.xlabel('Cases per 10,000')
        plt.ylabel('Frequency')
        plt.legend()
        plt.show()

    # Plot results
    plot_hypothesis_results(cases_per_10k, civilian_labor_force, 'Civilian Labor Force')
    plot_hypothesis_results(cases_per_10k, employed, 'Employed')
    plot_hypothesis_results(cases_per_10k, health_insurance_coverage, 'Health Insurance Coverage')
# Out:
#    countyFIPS      County Name State  StateFIPS  population  2020-06-01  \
# 0        1001  Autauga County     AL          1       55869         233
# 1        1003  Baldwin County     AL          1      223234         292
# 2        1005  Barbour County     AL          1       24686         172
# 3        1007     Bibb County     AL          1       22394          76
# 4        1009   Blount County     AL          1       57826          63
#
#    2020-06-02  2020-06-03  2020-06-04  2020-06-05  ...  2020-12-25_deaths  \
# 0         238         239         241         248  ...                 46
# 1         292         292         293         296  ...                151
# 2         175         177         177         183  ...                 32
# 3          76          76          76          76  ...                 42
# 4          63          63          63          64  ...                 58
#
#    2020-12-26_deaths  2020-12-27_deaths  2020-12-28_deaths  2020-12-29_deaths  \
# 0                 46                 47                 47                 47
# 1                151                152                152                156
# 2                 32                 32                 32                 32
# 3                 42                 42                 42                 42
# 4                 58                 58                 58                 58
#
#    2020-12-30_deaths  2020-12-31_deaths  2021-01-01_deaths  2021-01-02_deaths  \
# 0                 48                 48                 50                 50
# 1                160                161                169                169
# 2                 32                 32                 33                 33
# 3                 46                 46                 46                 46
# 4                 63                 63                 63                 63
#
#    2021-01-03_deaths
# 0                 50
# 1                169
# 2                 33
# 3                 46
# 4                 63
#
# [5 rows x 439 columns]
# countyFIPS           0
# County Name          0
# State                0
# StateFIPS            0
# population           0
#                     ..
# 2020-12-30_deaths    0
# 2020-12-31_deaths    0
# 2021-01-01_deaths    0
# 2021-01-02_deaths    0
# 2021-01-03_deaths    0
# Length: 439, dtype: int64
# Aggregated Cases after filling NaN:
#  0        378845.0
# 1       1158058.0
# 2        176208.0
# 3        151406.0
# 4        361287.0
#           ...
# 3137     159088.0
# 3138     159981.0
# 3139     109646.0
# 3140      43132.0
# 3141      28660.0
# Length: 3142, dtype: float64
# Cases per 10k:
#  0       11.541724
# 1       35.280882
# 2        5.368275
# 3        4.612668
# 4       11.006810
#           ...
# 3137     4.846705
# 3138     4.873910
# 3139     3.340426
# 3140     1.314040
# 3141     0.873143
# Length: 3142, dtype: float64
# Mean cases: 16.562545400450187
# High cases count: 2612, Low cases count: 530
# Overall - Civilian Labor Force - T-statistic: -12.457833872122912, P-value: 2.02689602593649e-31
# Mean cases: 16.562545400450187
# High cases count: 2612, Low cases count: 530
# Overall - Employed - T-statistic: -12.457833872122912, P-value: 2.02689602593649e-31
# Mean cases: 16.562545400450187
# High cases count: 2612, Low cases count: 530
# Overall - Health Insurance Coverage - T-statistic: -12.457833872122912, P-value: 2.02689602593649e-31
